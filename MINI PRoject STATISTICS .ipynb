# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 1: Understand Your Data
# ## Business Purpose: Familiarize yourself with who your customers are and what attributes  are available to you.

# %% [markdown]
# ### Load and preview the dataset.

# %%
df = pd.read_csv(r"C:\Users\Administrator\Downloads\DATAANALYTICS\Statistics\MINI PRoject\US_Customer_Insights_Dataset.csv")

# %%
df.head()
# Out:
#   CustomerID              Name       State    Education      Gender  Age  \
# 0  CUST10319       Scott Perez     Florida  High School  Non-Binary   47
# 1  CUST10695   Jennifer Burton  Washington       Master        Male   72
# 2  CUST10297   Michelle Rogers     Arizona       Master      Female   40
# 3  CUST10103  Brooke Hendricks       Texas       Master        Male   27
# 4  CUST10219       Karen Johns       Texas  High School      Female   28
#
#   Married  NumPets JoinDate TransactionDate  MonthlySpend  \
# 0     Yes        1  9/19/21          9/2/24       1281.74
# 1     Yes        0   4/5/24          6/2/24        429.46
# 2     Yes        2  7/24/24         2/28/25        510.34
# 3     Yes        0  8/12/23         3/29/25        396.47
# 4     Yes        1  12/6/21         7/24/22        139.68
#
#    DaysSinceLastInteraction
# 0                       332
# 1                       424
# 2                       153
# 3                       124
# 4                      1103

# %% [markdown]
# ### Check data types, unique values, and presence of nulls.

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10675 entries, 0 to 10674
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                10675 non-null  object
#  1   Name                      10675 non-null  object
#  2   State                     10675 non-null  object
#  3   Education                 10675 non-null  object
#  4   Gender                    10675 non-null  object
#  5   Age                       10675 non-null  int64
#  6   Married                   10675 non-null  object
#  7   NumPets                   10675 non-null  int64
#  8   JoinDate                  10675 non-null  datetime64[ns]
#  9   TransactionDate           10675 non-null  datetime64[ns]
#  10  MonthlySpend              10675 non-null  float64
#  11  DaysSinceLastInteraction  10675 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int64(3), object(6)
# memory usage: 1000.9+ KB

# %%
df["JoinDate"]= pd.to_datetime(df["JoinDate"])
df["TransactionDate"] = pd.to_datetime(df["TransactionDate"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10675 entries, 0 to 10674
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                10675 non-null  object
#  1   Name                      10675 non-null  object
#  2   State                     10675 non-null  object
#  3   Education                 10675 non-null  object
#  4   Gender                    10675 non-null  object
#  5   Age                       10675 non-null  int64
#  6   Married                   10675 non-null  object
#  7   NumPets                   10675 non-null  int64
#  8   JoinDate                  10675 non-null  datetime64[ns]
#  9   TransactionDate           10675 non-null  datetime64[ns]
#  10  MonthlySpend              10675 non-null  float64
#  11  DaysSinceLastInteraction  10675 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int64(3), object(6)
# memory usage: 1000.9+ KB

# %% [markdown]
# ### Understand which variables are categorical and which are numerical.

# %%
categorical_cols = df.select_dtypes(include=["object"])
categorical_cols.head()
# Out:
#   CustomerID              Name       State    Education      Gender Married
# 0  CUST10319       Scott Perez     Florida  High School  Non-Binary     Yes
# 1  CUST10695   Jennifer Burton  Washington       Master        Male     Yes
# 2  CUST10297   Michelle Rogers     Arizona       Master      Female     Yes
# 3  CUST10103  Brooke Hendricks       Texas       Master        Male     Yes
# 4  CUST10219       Karen Johns       Texas  High School      Female     Yes

# %%
numerical_cols = df.select_dtypes(include=["number"])
numerical_cols.head()
# Out:
#    Age  NumPets  MonthlySpend  DaysSinceLastInteraction
# 0   47        1       1281.74                       332
# 1   72        0        429.46                       424
# 2   40        2        510.34                       153
# 3   27        0        396.47                       124
# 4   28        1        139.68                      1103

# %% [markdown]
# ## Step 2: Descriptive Statistics

# %% [markdown]
#  ### Mean, median, std dev for Age, MonthlySpend, DaysSinceLastInteraction

# %%
df["Age"].agg(["mean","median","std"])
# Out:
# mean      49.474567
# median    49.000000
# std       18.221365
# Name: Age, dtype: float64

# %% [markdown]
# Conclusion: Mean and Median are same which tells us that the average age is 49, and the age data is in bell shape or age column follows normal distribution. Becaause STD is 18 ---> 49 - 18 = 31
#   49 + 18 = 67 , most customers are between 31-67 years old

# %%
df["MonthlySpend"].agg(["mean","median","std"])
# Out:
# mean      331.610315
# median    282.110000
# std       225.799253
# Name: MonthlySpend, dtype: float64

# %% [markdown]
# Conclusion: Because mean is greater than median we can say the data is right skewed and std is also high which means values are very spread out, it also tells us that some people spend more and some people spend very less.

# %%
df["DaysSinceLastInteraction"].agg(["mean","median","std"])
# Out:
# mean      538.469883
# median    445.000000
# std       398.766747
# Name: DaysSinceLastInteraction, dtype: float64

# %% [markdown]
# Conclusion: Because mean is greater than median  the data is right skewed and std is also high which means values are very spreadout from eachother and the dataset shows heterogeneous spending behavior with possible high-value outliers.

# %% [markdown]
# ### Mode for categorical variables: Gender, Education, Married

# %%
df[["Gender","Education","Married"]].mode()
# Out:
#   Gender Education Married
# 0   Male    Master      No

# %% [markdown]
# # Step 3: Data Visualization
# ## Business Purpose: Reveal patterns that numbers alone can’t show.

# %% [markdown]
# ### Plot histograms and boxplots for Age, MonthlySpend

# %%
sns.histplot(df["Age"],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# Conclusion: This is a multimodal graph, here we can see the age distribution is fairly equally distributed. There is no single clear peak.

# %%
plt.boxplot(df["Age"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2214658efd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2214658f250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2214658ee90>],
#  'medians': [<matplotlib.lines.Line2D at 0x2214658f4d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2214658f610>],
#  'means': []}

# %% [markdown]
# Conclusion: There are no outliers in age data.

# %%
sns.histplot(df["MonthlySpend"],kde=True)
# Out:
# <Axes: xlabel='MonthlySpend', ylabel='Count'>

# %% [markdown]
# Conclusion: This data is right skewed. We can say that some people are spending much more than others. Mostly people are spending around 250 to 500 and There is only one clear peak  in the distribution, occurring around 150–200 on the MonthlySpend

# %%
plt.boxplot(df["MonthlySpend"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x221466e74d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x221466e7750>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x221466e7390>],
#  'medians': [<matplotlib.lines.Line2D at 0x221466e79d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x221466e7b10>],
#  'means': []}

# %% [markdown]
# Conclusion: There are clearly many outliers abvove the upper line and because the medium line is very closer to the bottom line which tells us that the data is right skewed.It also tells us that there are some people who spend high amount.

# %% [markdown]
# ### Create a bar chart for Gender, Education, State

# %%
df["Gender"].value_counts().plot(kind="bar")
plt.title("Distribution of Genders")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Conclusion:  The distribution of genders is fairly balanced across all three categories. Male(3750) are  the highest, followed by Non-Binary (3475) and Female (3425). The difference between them is not very much.

# %%
df["Education"].value_counts().plot(kind="bar")
plt.ylabel("Count")
plt.title("Distribution according to Education Status")
# Out:
# Text(0.5, 1.0, 'Distribution according to Education Status')

# %% [markdown]
# Conclusion:In this graph we can see the people who has done Master are big spender whereas PhD spend less. But their difference is also not very big.

# %%
df["State"].value_counts().plot(kind="bar")
plt.title("Distribution According to States")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Conclusion: California has highest number of customer followed by Flordia than Ohio and at last Illinois.

# %% [markdown]
# ### Scatterplot: Age vs MonthlySpend

# %%
sns.scatterplot(x=df["Age"],y=df["MonthlySpend"])
# Out:
# <Axes: xlabel='Age', ylabel='MonthlySpend'>

# %% [markdown]
# Conclusion: There is no such relation between spending more or less according to age in this data,We can say that most of the people regardless of age are spending around 750.Spending pattern remain consistent across all age group.

# %% [markdown]
# ### KDE: Spending behavior by education level or marital status

# %%
sns.kdeplot(data=df,x="MonthlySpend",hue="Education")
# Out:
# <Axes: xlabel='MonthlySpend', ylabel='Density'>

# %% [markdown]
# Conclusion: Highest Peak is Master's and lowest Peak is Phd. All five group of students shows right skewed spending distribution. Highest Peak is around 250 for all.

# %%
sns.kdeplot(data=df,x="MonthlySpend",hue="Married")
# Out:
# <Axes: xlabel='MonthlySpend', ylabel='Density'>

# %% [markdown]
# Conclusion: Both Married and Non-Married people shows right skewed spending distribution. Most customers from both group spend under lower to medium range but some customers spend high from both group. Because high spender in both groups these also shows that both graphs are right skewed.Married people peak is lower compared to non-married group.

# %% [markdown]
# # Step 4: Bivariate Analysis
# ## Business Purpose: Check how customer attributes relate to one another.

# %% [markdown]
# ### Correlation matrix (numeric variables)

# %% [markdown]
# df[['Age','NumPets', 'MonthlySpend','DaysSinceLastInteraction' ]].corr()

# %% [markdown]
# Conclusion: All correlation values are close to 0 , which shows that there is really no real correlation between any of them.They all seem independent to eachother. Number of pets is really not that related to high monthly spending it is around 20%.

# %% [markdown]
# ### Crosstab of Gender vs Married

# %%
pd.crosstab(df["Gender"],df["Married"])
# Out:
# Married       No   Yes
# Gender
# Female      1797  1616
# Male        1892  1899
# Non-Binary  1894  1577

# %% [markdown]
# Conclusion: The distribution of genders is fairly balanced across all three categories. Male(3750) are  the highest, followed by Non-Binary (3475) and Female (3425). The difference between them is not very much.

# %% [markdown]
# ### Grouped stats: average MonthlySpend by State, Education, Gender

# %%
df.groupby("State")["MonthlySpend"].mean().sort_values(ascending=False)
# Out:
# State
# Arizona       341.489135
# Ohio          340.187860
# California    339.183492
# Illinois      332.589591
# New York      332.151244
# Washington    329.444078
# Georgia       328.354648
# Florida       327.696892
# Colorado      323.083462
# Texas         319.506770
# Name: MonthlySpend, dtype: float64

# %% [markdown]
# Conclusion: Arizona spends much more monthly compared to other states.

# %%
df.groupby("Education")["MonthlySpend"].mean().sort_values(ascending=False)
# Out:
# Education
# Master         334.252305
# High School    332.215712
# Bachelor       331.884753
# PhD            331.690090
# Associate      327.884408
# Name: MonthlySpend, dtype: float64

# %% [markdown]
# Conclusion: By Education status we can see Masters are spending much more than others and people who are Associates are spending less compared to all others.

# %%
df.groupby("Gender")["MonthlySpend"].mean().sort_values(ascending=False)
# Out:
# Gender
# Male          333.174068
# Female        331.361310
# Non-Binary    330.147240
# Name: MonthlySpend, dtype: float64

# %% [markdown]
# Conclusion: Males are spending more compared to others.

# %% [markdown]
# # Step 5: Formulate Hypotheses
# ## Business Purpose: Turn business questions into statistical tests.

# %% [markdown]
# ### Do males and females spend differently?

# %%
male= df.loc[df["Gender"]=="Male","MonthlySpend"]
female= df.loc[df["Gender"]=="Female","MonthlySpend"]

# %%
from scipy.stats import ttest_ind
t_stat, p_value = ttest_ind(male,female,equal_var=False)
alpha = 0.05
print("p value is", round(p_value,3))
if p_value>alpha:
    print("Because P_Value",round(p_value,3)," is greater than the alpha(0.05), therefore we fail to reject the null hypothesis.")
else:
    print("Because P_value is less than alpha we are rejecting the null hypothesis")
# Out:
# p value is 0.735
# Because P_Value 0.735  is greater than the alpha(0.05), therefore we fail to reject the null hypothesis.

# %% [markdown]
# ### Does education level impact average monthly spend?

# %%
df["Education"].value_counts()
# Out:
# Education
# Master         2269
# Associate      2153
# Bachelor       2127
# High School    2120
# PhD            2006
# Name: count, dtype: int64

# %%
phd = df.loc[df["Education"]=="PhD","MonthlySpend"]
master= df.loc[df["Education"]=="Master","MonthlySpend"]
bachelor = df.loc[df["Education"]=="Bachelor","MonthlySpend"]
associate = df.loc[df["Education"]=="Associate","MonthlySpend"]
highschool = df.loc[df["Education"]=="High School","MonthlySpend"]

# %%
from scipy.stats import f_oneway
f_stat,p_value = f_oneway(phd,master,bachelor,associate,highschool)
print(p_value)
# Out:
# 0.922359467759936

# %% [markdown]
# ### Is marital status related to the number of pets owned? [Only for DS Students]

# %% [markdown]
# Null Hypothesis: Martial status and pets owned is independent
#   Alternate Hypothesis = Martial Status and pets owned is dependent.

# %%
Table = pd.crosstab(df["Married"],df["NumPets"])
alpha = 0.05

# %%
from scipy.stats import chi2_contingency
chi2, p_value, dof, expected = chi2_contingency(Table)
print(p_value)
if p_value>alpha:
    print("Because p_value is greater than alpha we are accepting the Null Hypothesis")
else:
    print("Because p_value is less than alpha we are rejecting the Null Hypothesis")
# Out:
# 2.3957232932397494e-37
# Because p_value is less than alpha we are rejecting the Null Hypothesis

# %% [markdown]
# ### Are older people less active?

# %% [markdown]
# Null Hypothesis: There is no relationship between age and days since last interaction
# Alternate Hypothesis: There is releationship between age and days since last interaction

# %%
alpha = 0.05

# %%
from scipy.stats import pearsonr
corr, p_value = pearsonr(df["Age"],df["DaysSinceLastInteraction"])
print(p_value)
if p_value>alpha:
    print("We accept the null hypothesis because p_value is greater than alpha")
else:
    print("We reject the null hypothesis because p_value is lesser than alpha")
# Out:
# 0.6816905437300954
# We accept the null hypothesis because p_value is greater than alpha

# %% [markdown]
# ### Does state-wise spend vary significantly?

# %% [markdown]
# Null Hypothesis: There is no relationship between State and monthly spend
# Alternate Hypothesis: There is releationship between State and monthly spend

# %%
df["State"].value_counts()
# Out:
# State
# California    1180
# Florida       1152
# Ohio          1145
# Arizona       1087
# New York      1085
# Georgia       1080
# Washington    1030
# Colorado      1014
# Texas          997
# Illinois       905
# Name: count, dtype: int64

# %%
aplha = 0.05

# %%
California =df.loc[df["State"]=="California","MonthlySpend"]
Florida = df.loc[df["State"]=="Florida","MonthlySpend"]
Ohio = df.loc[df["State"]=="Ohio","MonthlySpend"]
Arizona = df.loc[df["State"]=="Arizona","MonthlySpend"]
New_York = df.loc[df["State"]=="New York","MonthlySpend"]
Georgia = df.loc[df["State"]=="Georgia","MonthlySpend"]
Washington = df.loc[df["State"]=="Washington","MonthlySpend"]
Colorado = df.loc[df["State"]=="Colorado","MonthlySpend"]
Texas = df.loc[df["State"]=="Texas","MonthlySpend"]
Illinois = df.loc[df["State"]=="Illinois","MonthlySpend"]

# %%
from scipy.stats import f_oneway
f_stat,p_value = f_oneway(California,Florida,Ohio,Arizona,New_York,Georgia,Washington,Colorado,Texas,Illinois)
print(p_value)
if p_value>alpha:
    print("We accept the null hypothesis because p_value is greater than alpha")
else:
    print("We reject the null hypothesis because p_value is lesser than alpha")
# Out:
# 0.34571886479238273
# We accept the null hypothesis because p_value is greater than alpha

# %% [markdown]
# ### 5 Takeaways

# %% [markdown]
# ### (1) Gender does not affect spending that much. Both Male and Female spend similarly. But still Males were spending more.
# ### (2) Education does not afftect that much in spending. Because all of them were right skewed data , where master shows the highest peak and phd showed lowest peak but still they both had outliers.
# ### (3) Married Customers owned more pets compared to non-married Customers.
# ### (4) Age does not affect spending behaviour because the data was in bell shaped . This also means Older customers are equally active as younger ones.
# ### (5) Spending is Highly Right Skewed. which means a small group of high value customers drive majority of revenue.
